# %%
import pandas as pd

# %%
basics_df = pd.read_csv('../data/zippedData/imdb.title.basics.csv.gz', compression = 'gzip')
basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
#slit the genres in single string into a list
[x.split(',') for x in basics_df['genres']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-802134f7c7f0> in <module>()
#       1 #slit the genres in single string into a list
# ----> 2 [x.split(',') for x in basics_df['genres']]
#
# <ipython-input-4-802134f7c7f0> in <listcomp>(.0)
#       1 #slit the genres in single string into a list
# ----> 2 [x.split(',') for x in basics_df['genres']]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
#checking the type of x as last result of it being a float was unexpected
[type(x) for x in basics_df['genres']]
# Out:
# [str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  float,
#  str,
#  str,
#  str,
#  str,
#  str,
#  float,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  float,
#  str,
#  str,
#  str,
#  str,
#  float,
#  str,
#  str,
#  str,
#  float,
#  float,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
# ...

# %%
#checking for Nan values
basics_df.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
#replacing NaN in genres with 'unknown'
basics_df['genres'] = basics_df['genres'].fillna('unknown')

# %%
#checking to see if there are na's in genres
basics_df.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres                 0
# dtype: int64

# %%
#split single string of genres into a list of genres
basics_df['genres'] = [x.split(',') for x in basics_df['genres']]

# %%
#replace NaN in runtime with 0, which will be obviously not correct, but a float
basics_df['runtime_minutes'] = basics_df['runtime_minutes'].fillna(0)

# %%
ratings_df = pd.read_csv('../data/zippedData/imdb.title.ratings.csv.gz', compression = 'gzip')
ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
ratings_df.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
print(len(basics_df))
len(ratings_df)
# Out:
# 146144
# 73856

# %%
ratings_df.join(basics_df.set_index('tconst'), on = 'tconst')
# Out:
#            tconst  averagerating  numvotes  \
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
#                                            primary_title  \
# 0                                       Laiye Je Yaarian
# 1                                             Borderless
# 2                                              Just Inès
# 3                                 The Legend of Hercules
# 4                                              Até Onde?
# ...                                                  ...
# ...

# %%
len(ratings_df)
# Out:
# 73856

# %%
ratings_df.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64
